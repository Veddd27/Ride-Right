# %%
import os

# Go into your project folder if needed

# Run main.py
# !python main.py

# %%
# !python -u main.py
# Out:
# ^C

# %%
# !python -V
# Out:
# Python 3.13.9

# %%
# !python -u main.py
# Out:
# STARTING MODEL PIPELINE...
#
# Linear Regression
# RMSE: 9.7213
# MAE: 6.0024
# R2: 0.0040
#
# Random Forest
# RMSE: 4.9868
# MAE: 2.4572
# R2: 0.7379
#
# XGBoost
# RMSE: 5.0144
# MAE: 2.3154
# R2: 0.7350
# Traceback (most recent call last):
#   File "C:\Users\vedam\Ride-Right\main.py", line 47, in <module>
#     with open("models/model.pkl", "wb") as f:
#          ~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'models/model.pkl'
